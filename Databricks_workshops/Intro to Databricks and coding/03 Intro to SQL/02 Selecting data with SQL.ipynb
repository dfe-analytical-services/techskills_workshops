# %% [markdown]
# # SELECT
# This operation does exactly what it says: it selects the table.
#
# The `SELECT` operation is partnered with `FROM` to help direct the query to where it should retieve data from.
#
# To query a full table, we would use
# ```
# SELECT * FROM tablename
# ```
# where the asterisk `*` denotes all columns.
#
# Try it out by running the below code;

# %%
# %sql
SELECT * FROM catalog_40_copper_analyst_training.steam.games_ranking

# %% [markdown]
# ### Activity
# We can be more specific in our select query to pick only certain columns from our table.
#
# Could you write a select query to SELECT only the `game_name`, `rank_type`, and `rank` columns from the `catalog_40_copper_analyst_training.steam.games_ranking` table?

# %%
# %sql
/* Write your code here */



/* A hint can be found below this section if you get stuck */

# %%
from IPython.display import display, HTML

hint_html = """
<div style="border:1px solid #ccc; padding:16px; border-radius:8px; background-color:#f9f9f9; margin:10px 0;">
  <button onclick="var x=document.getElementById('hint-content'); x.style.display = x.style.display === 'none' ? 'block' : 'none';" style="background-color:#0073e6; color:white; border:none; padding:8px 16px; border-radius:4px; cursor:pointer;">
    Show Hint
  </button>
  <div id="hint-content" style="display:none; margin-top:10px;">
    <b>Hint:</b> Use <code>SELECT</code> with the column names you want, separated by commas.<br>
    Example: <code>SELECT column1, column2 FROM tablename;</code>
  </div>
</div>
"""

display(HTML(hint_html))

# %% [markdown]
# ## DISTINCT
#
# You can use `DISTINCT` in a `SELECT` query to only retrieve records that are unique. Imagine the query is saying "select only unique rows from..."
#
# Have a go at the question below to see if you can guess where the `DISTINCT` operation goes in the query.

# %%
displayHTML("""
<style>
  .quiz-container { font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif; max-width: 700px; padding: 1rem; }
  .quiz-title { font-size: 1.5rem; font-weight: 600; margin-bottom: 1.5rem; color: #1a1a1a; }
  .question { margin-bottom: 1.5rem; padding: 1rem; border: 1px solid #e0e0e0; border-radius: 8px; background: #fafafa; }
  .question h3 { margin: 0 0 0.75rem 0; font-size: 1rem; color: #333; }
  .options label { display: block; padding: 0.5rem 0.75rem; margin: 0.25rem 0; border-radius: 4px; cursor: pointer; transition: background 0.2s; }
  .options label:hover { background: #e8f0fe; }
  .options input[type='radio'] { margin-right: 0.5rem; }
  .feedback { margin-top: 0.5rem; padding: 0.5rem 0.75rem; border-radius: 4px; font-weight: 500; display: none; }
  .feedback.correct { background: #d4edda; color: #155724; display: block; }
  .feedback.incorrect { background: #f8d7da; color: #721c24; display: block; }
  .submit-btn { margin-top: 1.5rem; padding: 0.6rem 1.5rem; background: #0066cc; color: white; border: none; border-radius: 4px; font-size: 1rem; cursor: pointer; }
  .submit-btn:hover { background: #0052a3; }
</style>

<div class="quiz-container">
  <div class="quiz-title">&#x2705; Quick Quiz: SQL SELECT with DISTINCT</div>

  <div class="question" id="q1">
    <h3>1. Which SQL query correctly selects only unique values from the <code>rank_type</code> column in the <code>catalog_40_copper_analyst_training.steam.games_ranking</code> table?</h3>
    <div class="options">
      <label><input type="radio" name="q1" value="a"> SELECT DISTINCT rank_type FROM catalog_40_copper_analyst_training.steam.games_ranking;</label>
      <label><input type="radio" name="q1" value="b"> SELECT rank_type FROM catalog_40_copper_analyst_training.steam.games_ranking DISTINCT;</label>
      <label><input type="radio" name="q1" value="c"> SELECT rank_type FROM catalog_40_copper_analyst_training.steam.games_ranking;</label>
      <label><input type="radio" name="q1" value="d"> SELECT * FROM catalog_40_copper_analyst_training.steam.games_ranking DISTINCT rank_type;</label>
    </div>
    <div class="feedback" id="fb1"></div>
  </div>
  <button class="submit-btn" onclick="checkAnswers()">Check Answer</button>
</div>

<script>
  const answers = { q1: 'a' };
  const explanations = {
    q1: "The correct syntax is <code>SELECT DISTINCT column FROM tablename;</code> to retrieve unique values from a column."
  };

  function checkAnswers() {
    for (let q in answers) {
      const selected = document.querySelector(`input[name="${q}"]:checked`);
      const fb = document.getElementById('fb' + q.charAt(1));
      if (selected && selected.value === answers[q]) {
        fb.className = 'feedback correct';
        fb.innerHTML = '&#x2705; Correct! ' + explanations[q];
      } else if (selected) {
        fb.className = 'feedback incorrect';
        fb.innerHTML = '&#x274c; Incorrect. ' + explanations[q];
      } else {
        fb.className = 'feedback incorrect';
        fb.innerHTML = '&#x26a0;&#xfe0f; No answer selected. ' + explanations[q];
      }
    }
  }
</script>
""")

# %% [markdown]
# ### Activity
# Try it yourself.
#
# Could you write a select query to SELECT only unique rows in the the `game_name` column from the `catalog_40_copper_analyst_training.steam.games_ranking` table?

# %%
# %sql
/* Write your code here */



/* If you get stuck, make sure to check out the quick quiz above */

# %% [markdown]
# ## WHERE
#
# Another operation you can use with `SELECT` to be more specific is `WHERE`.
#
# This will only select data that meets a specified condition.
#
# To add contions with `WHERE` you will need to use logical operators, such as;
# - `=` for equal to,
# - `>` for greater than,
# - `>=` for greater that or equal to,
# - `<` for less than,
# - `<=` for less than or equal to,
# - `<>` for not equal to
#
# If the condtion relates to a character sting (e.g. selecting all rows where the game_name collumn is equal to 'Terraria') you must enlcose the string in single quotation marks. For numeric conditions, (e.g. selecting all rows where the rank column is equal to 1) the quotations are not needed.
#
# Have a go at answering the below question to learn where `WHERE` belongs in an SQL query.

# %%
displayHTML("""
<style>
  .quiz-container { font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif; max-width: 700px; padding: 1rem; }
  .quiz-title { font-size: 1.5rem; font-weight: 600; margin-bottom: 1.5rem; color: #1a1a1a; }
  .question { margin-bottom: 1.5rem; padding: 1rem; border: 1px solid #e0e0e0; border-radius: 8px; background: #fafafa; }
  .question h3 { margin: 0 0 0.75rem 0; font-size: 1rem; color: #333; }
  .options label { display: block; padding: 0.5rem 0.75rem; margin: 0.25rem 0; border-radius: 4px; cursor: pointer; transition: background 0.2s; }
  .options label:hover { background: #e8f0fe; }
  .options input[type='radio'] { margin-right: 0.5rem; }
  .feedback { margin-top: 0.5rem; padding: 0.5rem 0.75rem; border-radius: 4px; font-weight: 500; display: none; }
  .feedback.correct { background: #d4edda; color: #155724; display: block; }
  .feedback.incorrect { background: #f8d7da; color: #721c24; display: block; }
  .submit-btn { margin-top: 1.5rem; padding: 0.6rem 1.5rem; background: #0066cc; color: white; border: none; border-radius: 4px; font-size: 1rem; cursor: pointer; }
  .submit-btn:hover { background: #0052a3; }
</style>

<div class="quiz-container">
  <div class="quiz-title">&#x2705; Quick Quiz: SQL SELECT with WHERE</div>

  <div class="question" id="q1">
    <h3>1. Which SQL query correctly selects rows from <code>catalog_40_copper_analyst_training.steam.games_ranking</code> where the game genre is strategy?</h3>
    <div class="options">
      <label><input type="radio" name="q1" value="a"> SELECT * FROM catalog_40_copper_analyst_training.steam.games_ranking WHERE genre = Strategy;</label>
      <label><input type="radio" name="q1" value="b"> SELECT WHERE genre = 'Strategy' FROM catalog_40_copper_analyst_training.steam.games_ranking;</label>
      <label><input type="radio" name="q1" value="c"> SELECT * FROM catalog_40_copper_analyst_training.steam.games_ranking WHERE genre = 'Strategy';</label>
      <label><input type="radio" name="q1" value="d"> SELECT * FROM catalog_40_copper_analyst_training.steam.games_ranking WHERE 'Strategy';</label>
    </div>
    <div class="feedback" id="fb1"></div>
  </div>
  <button class="submit-btn" onclick="checkAnswers()">Check Answer</button>
</div>

<script>
  const answers = { q1: 'c' };
  const explanations = {
    q1: "The correct syntax is <code>SELECT column FROM tablename WHERE logical condition;</code> to retrieve specific rows from a table. When the condition inlcudes a character string, it must be enclosed in single quotes."
  };

  function checkAnswers() {
    for (let q in answers) {
      const selected = document.querySelector(`input[name="${q}"]:checked`);
      const fb = document.getElementById('fb' + q.charAt(1));
      if (selected && selected.value === answers[q]) {
        fb.className = 'feedback correct';
        fb.innerHTML = '&#x2705; Correct! ' + explanations[q];
      } else if (selected) {
        fb.className = 'feedback incorrect';
        fb.innerHTML = '&#x274c; Incorrect. ' + explanations[q];
      } else {
        fb.className = 'feedback incorrect';
        fb.innerHTML = '&#x26a0;&#xfe0f; No answer selected. ' + explanations[q];
      }
    }
  }
</script>
""")

# %% [markdown]
# ## WHERE conditions
#
# Beyond simple logical operations, you can also specify more complex conditions using operations including;
# - `AND`, specify multiple conitions that must all be met,
# ```
# SELECT * FROM tablename WHERE (column1 = 'Condition 1') AND (column2 <> 'Condition 2');
# ```
# - `OR`, specify multiple conditions, where rows meeting at least 1 conditon are selected,
# ```
# SELECT * FROM tablename WHERE (column1 = 'Condition 1') OR (column2 <> 'Condition 2');
# ```
# - `IN`, selects rows where items in a coulm are in a list of alowed values,
# ```
# SELECT * FROM tablename WHERE column1 IN ('Condition 1', 'Condition 2', 'Condition 3');
# ```
# - `NOT IN`, is the inverse, which selects rows where items in a coulm do nat match items in a list of alowed values,
# ```
# SELECT * FROM tablename WHERE column1 NOT IN ('Condition 1', 'Condition 2', 'Condition 3');
# ```
# - `BETWEEN`, selects rows where items are between two numeric values,
# ```
# SELECT * FROM tablename WHERE column1 BETWEEN 0 AND 100;
# ```
#
# ### LIKE
#
# `LIKE` is used to select rows that match a pattern.
#
# The pattern can be specificed using `_` and `%`.
#
# - `_` inidcates a single character, so 'a_t' would match to 'ant' and 'act',
# - `%` incicates multiple characters, so 'a%t` would match to 'ant' and 'act', and also 'accomplishment' and 'ambivalent'
#    - `%` also include matching to zero characters, so 'a%t' would also match to 'at'
#
# To note, the patterns in `LIKE` are case sensitive, so 'a_t' would **not match** to 'Ant'. Consider first using `LOWER` or `UPPER` to transform the column to all lower case or all upper case before pattern matching, if the case is not important.
#
# Test your knowledge on more complex conditions with the quick quiz and activity below!

# %%
displayHTML("""
<style>
  .quiz-container { font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif; max-width: 700px; padding: 1rem; }
  .quiz-title { font-size: 1.5rem; font-weight: 600; margin-bottom: 1.5rem; color: #1a1a1a; }
  .question { margin-bottom: 1.5rem; padding: 1rem; border: 1px solid #e0e0e0; border-radius: 8px; background: #fafafa; }
  .question h3 { margin: 0 0 0.75rem 0; font-size: 1rem; color: #333; }
  .options label { display: block; padding: 0.5rem 0.75rem; margin: 0.25rem 0; border-radius: 4px; cursor: pointer; transition: background 0.2s; }
  .options label:hover { background: #e8f0fe; }
  .options input[type='radio'] { margin-right: 0.5rem; }
  .feedback { margin-top: 0.5rem; padding: 0.5rem 0.75rem; border-radius: 4px; font-weight: 500; display: none; }
  .feedback.correct { background: #d4edda; color: #155724; display: block; }
  .feedback.incorrect { background: #f8d7da; color: #721c24; display: block; }
  .submit-btn { margin-top: 1.5rem; padding: 0.6rem 1.5rem; background: #0066cc; color: white; border: none; border-radius: 4px; font-size: 1rem; cursor: pointer; }
  .submit-btn:hover { background: #0052a3; }
</style>

<div class="quiz-container">
  <div class="quiz-title">&#x2705; Quick Quiz: SQL SELECT with WHERE and LIKE</div>

  <div class="question" id="q1">
    <h3>1. Which SQL query correctly selects unique game names from <code>catalog_40_copper_analyst_training.steam.games_ranking</code> where the game ends with "2"?</h3>
    <div class="options">
      <label><input type="radio" name="q1" value="a"> SELECT DISTINCT game_name FROM catalog_40_copper_analyst_training.steam.games_ranking WHERE game_name = '%2';</label>
      <label><input type="radio" name="q1" value="b"> SELECT DISTINCT game_name FROM catalog_40_copper_analyst_training.steam.games_ranking WHERE game_name LIKE '%2';</label>
      <label><input type="radio" name="q1" value="c"> SELECT game_name FROM catalog_40_copper_analyst_training.steam.games_ranking WHERE game_name LIKE '%2';</label>
      <label><input type="radio" name="q1" value="d"> SELECT DISTINCT game_name FROM catalog_40_copper_analyst_training.steam.games_ranking WHERE game_name LIKE "%2";</label>
    </div>
    <div class="feedback" id="fb1"></div>
  </div>
  <button class="submit-btn" onclick="checkAnswers()">Check Answer</button>
</div>

<script>
  const answers = { q1: 'b' };
  const explanations = {
    q1: "The correct syntax is <code>SELECT column FROM tablename WHERE column LIKE 'pattern';</code> to retrieve specific rows from a table. The pattern must be enclosed in single quotes."
  };

  function checkAnswers() {
    for (let q in answers) {
      const selected = document.querySelector(`input[name="${q}"]:checked`);
      const fb = document.getElementById('fb' + q.charAt(1));
      if (selected && selected.value === answers[q]) {
        fb.className = 'feedback correct';
        fb.innerHTML = '&#x2705; Correct! ' + explanations[q];
      } else if (selected) {
        fb.className = 'feedback incorrect';
        fb.innerHTML = '&#x274c; Incorrect. ' + explanations[q];
      } else {
        fb.className = 'feedback incorrect';
        fb.innerHTML = '&#x26a0;&#xfe0f; No answer selected. ' + explanations[q];
      }
    }
  }
</script>
""")

# %% [markdown]
# ### Activity
#
# Give it a go yourself.
#
# In the space below, can you write code to select the names of the top 5 ranked `Adventure` games based on their `Review`.

# %%
# %sql
/* Write your code here */



/* If you get stuck, make sure to check out the WHERE conditions above */

# %% [markdown]
# ## ORDER BY
#
# When selecting data, there is no guarantee that the data will be in any specific order.
#
# However, you can use the `ORDER BY` operation to sort columns in ascending, `ASC`, or descending, `DESC` order. By default (when neither are specified), `ORDER BY` sorts in ascending order.
#
# You can specify multiple columns to sort, and the sorts will occur in the oder of appearance. For example,
#
# ```
# SELECT * FROM catalog_40_copper_analyst_training.steam.games_ranking
# ORDER BY rank ASC, game_name ASC;
# ```
#
# will first sort rank in ascending order. Then for each unique game name within each rank (all games with rank 1, all games with rank 2 and so on), will be sorted alphabetically.
#
# Run the code below to explore how it works, then answer a question to check your understanding.

# %%
# %sql
/* Run this code below */

SELECT * FROM catalog_40_copper_analyst_training.steam.games_ranking ORDER BY rank ASC, LOWER(game_name) ASC;

/* Take note of how the data is now sorted */

# %%
displayHTML("""
<style>
  .quiz-container { font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Roboto, sans-serif; max-width: 700px; padding: 1rem; }
  .quiz-title { font-size: 1.5rem; font-weight: 600; margin-bottom: 1.5rem; color: #1a1a1a; }
  .question { margin-bottom: 1.5rem; padding: 1rem; border: 1px solid #e0e0e0; border-radius: 8px; background: #fafafa; }
  .question h3 { margin: 0 0 0.75rem 0; font-size: 1rem; color: #333; }
  .options label { display: block; padding: 0.5rem 0.75rem; margin: 0.25rem 0; border-radius: 4px; cursor: pointer; transition: background 0.2s; }
  .options label:hover { background: #e8f0fe; }
  .options input[type='radio'] { margin-right: 0.5rem; }
  .feedback { margin-top: 0.5rem; padding: 0.5rem 0.75rem; border-radius: 4px; font-weight: 500; display: none; }
  .feedback.correct { background: #d4edda; color: #155724; display: block; }
  .feedback.incorrect { background: #f8d7da; color: #721c24; display: block; }
  .submit-btn { margin-top: 1.5rem; padding: 0.6rem 1.5rem; background: #0066cc; color: white; border: none; border-radius: 4px; font-size: 1rem; cursor: pointer; }
  .submit-btn:hover { background: #0052a3; }
</style>

<div class="quiz-container">
  <div class="quiz-title">&#x2705; Quick Quiz: SQL SELECT with ORDER BY</div>

  <div class="question" id="q1">
    <h3>1. Which SQL query correctly selects unique game names from <code>catalog_40_copper_analyst_training.steam.games_ranking</code> ordered alphabetically?</h3>
    <div class="options">
      <label><input type="radio" name="q1" value="a"> SELECT DISTINCT game_name FROM catalog_40_copper_analyst_training.steam.games_ranking ORDER BY game_name ASC;</label>
      <label><input type="radio" name="q1" value="b"> SELECT DISTINCT game_name FROM catalog_40_copper_analyst_training.steam.games_ranking ORDER BY game_name DESC;</label>
      <label><input type="radio" name="q1" value="c"> SELECT DISTINCT game_name FROM catalog_40_copper_analyst_training.steam.games_ranking ORDER BY LOWER(game_name);</label>
      <label><input type="radio" name="q1" value="d"> SELECT DISTINCT * FROM catalog_40_copper_analyst_training.steam.games_ranking ORDER BY game_name;</label>
    </div>
    <div class="feedback" id="fb1"></div>
  </div>
  <button class="submit-btn" onclick="checkAnswers()">Check Answer</button>
</div>

<script>
  const answers = { q1: 'c' };
  const explanations = {
    q1: "The correct syntax is <code>SELECT DISTINCT game_name FROM catalog_40_copper_analyst_training.steam.games_ranking ORDER BY LOWER(game_name);</code> ORDER BY is case sensitive, and will sort lower case letters after upper case, to sort purely alpabettically use <code>LOWER</code> to fix the names to lower case before ordering."
  };

  function checkAnswers() {
    for (let q in answers) {
      const selected = document.querySelector(`input[name="${q}"]:checked`);
      const fb = document.getElementById('fb' + q.charAt(1));
      if (selected && selected.value === answers[q]) {
        fb.className = 'feedback correct';
        fb.innerHTML = '&#x2705; Correct! ' + explanations[q];
      } else if (selected) {
        fb.className = 'feedback incorrect';
        fb.innerHTML = '&#x274c; Incorrect. ' + explanations[q];
      } else {
        fb.className = 'feedback incorrect';
        fb.innerHTML = '&#x26a0;&#xfe0f; No answer selected. ' + explanations[q];
      }
    }
  }
</script>
""")
