-- %% [markdown]
-- To cover:
-- - Cloning and connetcing to DevOps
-- - Key differences
-- - Compute - differences between clusters (SQL warehouse, personal and shared)
-- - Navigation
-- - Unity catalog, schemas, tables
-- - Workspaces
--
-- Based on: https://dfe-analytical-services.github.io/analysts-guide/ADA/databricks_fundamentals.html#key-differences
